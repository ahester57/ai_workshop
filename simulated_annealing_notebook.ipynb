# %% [markdown]
# # Simulated Annealing
#
# A simulated annealing process to determine the optimal weight values of an artificial neuron.
# Python 3.8+ is required.
#
# ```
# function SIMULATED-ANNEALING(problem, schedule) returns a solution State
#   current <- problem.INITIAL
#   for t = 1 to inf do
#       T <- schedule(t)
#       if T = 0 then return current
#       next <- a randomly selected successor of current
#       delta_E <- VALUE(current) - VALUE(next)
#       if delta_E > 0 then current <- next
#       else current <- next only with probability e^(-delta_E/T)
# ```
#
#
# ## Development
#
# Create the virtual environment, enter into it with `source`, and install the package locally:
#
# ```bash
# $ python -m venv .venv
# $ source .venv/Scripts/activate
# (.venv)
# $ python -m pip install -e ".[dev]"
# ```
#
# See this reference for [installing Python packages](https://packaging.python.org/en/latest/tutorials/installing-packages/).
#
# Now you can run the application from within the virtual environment:
#
# ```bash
# python -m simulated_annealing
# ```
#
# ### Test Suite
# Run tests:
#
# ```bash
# (.venv)
# $ python -m pytest -v tests/
# ```
#
#
# ### Documentation
#
# Build documentation:
#
# ```bash
# (.venv)
# $ python -m sphinx -M html docs docs/_build
# ```
#
#
# ## Installation
#
# Packaging and distributing a Python application is dependent on the target
# operating system(s) and execution environment, which could be a Python virtual
# environment, Linux container, or native application.
#
# Install the application to a self-contained Python virtual environment:
#
# ```bash
# (.venv)
# $ python -m pip install <project source>
# $ cp -r <project source>/etc .venv/
# $ .venv/Scripts/simulated_annealing --help
# ```
#
#
# ## Execution
#
# The installed application includes a wrapper script for command line execution.
# The location of this scripts depends on how the application was installed.
#
# ---
#
# ### Configuration
#
# The application uses `TOML` files for configuration. Configuration supports
# runtime parameter substitution via a shell-like variable syntax, *i.e.*
# `var = ${VALUE}`. CLI invocation will use the current environment for
# parameter substitution, which makes it simple to pass host-specific values
# to the application without needing to change the config file for every
# installation.
#
# ```toml
#     mailhost = $SENDMAIL_HOST
# ```
#
# ### Logging
#
# The application uses standard `Python logging`. All loggins is to `STDERR`,
# nd the logging level can be set via the config file or on the command line.
#
#
# * [TOML](https://toml.io)
# * [Python logging](https://docs.python.org/3/library/logging.html)
#
# ---

# %%
""" Implement the anneal command.

```
function SIMULATED-ANNEALING(problem, schedule) returns a solution State
  current <- problem.INITIAL
  for t = 1 to inf do
      T <- schedule(t)
      if T = 0 then return current
      next <- a randomly selected successor of current
      delta_E <- VALUE(current) - VALUE(next)
      if delta_E > 0 then current <- next
      else current <- next only with probability e^(-delta_E/T)
```

Stuart Russel, Peter Norvig. "Artificial Intelligence: A Modern Approach, 4th Edition" (2021)
"""
import numpy as np

from graphlib import TopologicalSorter
from typing import Callable, override

try:
    import matplotlib.pyplot as plt
    import networkx as nx
except ModuleNotFoundError:
    plt = None
    nx = None


class Neuron(object):
    DIM_W = 3

    def __init__(self, *weights:tuple[float]) -> None:
        """Initialize an instance of Neuron.

        :param weights: Tuple of weight values.
        :type weights: tuple[float]
        :raises TypeError: If weights is not of length .node.Neuron.DIM_W.
        """
        print("initializing %s", self.__class__.__name__)
        if weights is None or len(weights) != self.DIM_W:
            raise TypeError(f'weights : tuple[float] : Must be of length {self.DIM_W}.')
        self.weights = weights
        self.error = 2.

    def score(self, x, y) -> float:
        return 1 / (1 + np.exp(self.weights[0] * x + self.weights[1] * y + self.weights[2]))

    @override
    def __repr__(self) -> str:
        return f'Neuron#{hash(self)}:{self.weights}. err={self.error}'
 
    @override
    def __hash__(self) -> int:
        return hash(self.weights)

    @override
    def __eq__(self, other) -> bool:
        return self.weights == other.weights


class ProblemGraph(TopologicalSorter):

    def __init__(self, initial:Neuron) -> None:
        """Initialize an instance of ProblemGraph.

        :param initial: Neuron
        :type initial: Neuron
        :param evaluate: The evaluation function
        :type evaluate: Callable
        :raises TypeError: If initial is None
        """
        print("initializing %s", self.__class__.__name__)
        if initial is None:
            raise TypeError("initial : Neuron - Cannot be None")
        super().__init__({initial: {}})
        self.initial : Neuron = self._node2info[initial].node
        self.finished_graph = None

    def evaluate_node(self, node:Neuron) -> float:
        """Initialize a Neuron as a potential NAND gate.

        :param initial: Neuron
        :type initial: Neuron
        :return: Sum of errors for each combination
        :rtype: float
        """
        node.error = np.sum([
            np.abs(1 - node.score(0, 0)),
            np.abs(1 - node.score(0, 1)),
            np.abs(1 - node.score(1, 0)),
            np.abs(0 - node.score(1, 1))
        ])
        return node.error

    @property
    def graph(self) -> dict[Neuron, list[Neuron]]:
        if self.finished_graph is None:
            self.finished_graph = dict([(self._node2info[n].node, self._node2info[n].successors) for n in self._node2info])
        return self.finished_graph

    def __repr__(self) -> str:
        return f'ProblemGraph: {self.graph}'


def _anneal_step(problem:ProblemGraph, T:float, current:Neuron, successor:Neuron) -> Neuron:
    """ Execute one step of the simulated annealing function.
    
    :param problem: The problem definition.
    :type problem: ProblemGraph
    :param T: Current temperature.
    :type T: float
    :param current: The current node, searching for a greener pasture.
    :type current: Neuron
    :param successor: One of the neighboring nodes, enticing.
    :type successor: Neuron
    :return: Either the current or successor node
    :rtype: Neuron
    """
    delta_E = problem.evaluate_node(current) - problem.evaluate_node(successor)
    print(delta_E)
    if delta_E > 0:
        print("Taking successor as better option (exploitation)")
        problem.add(successor, current) # Trace the path
        return successor
    else:
        print(T)
        probability = np.exp(delta_E / T)
        if np.random.default_rng().uniform() < probability:
            print("Taking successor with probability %d%s (exploration)", probability*100, '%')
            problem.add(successor, current) # Trace the path
            return successor
    return current


def main(problem:ProblemGraph|None=None, schedule:Callable=lambda x : x / 1.002) -> ProblemGraph:
    """ Execute the simulated annealing algorithm.
    
    :param problem: The problem definition.
    :type problem: ProblemGraph
    :param schedule: Temperature function
    :type schedule: Callable
    :return: The problem with solution search graph.
    :rtype: ProblemGraph
    """
    print("executing anneal command")
    assert problem is None or type(problem) == ProblemGraph
    if problem is None:
        problem = ProblemGraph(Neuron(0, 0, 0))
    if schedule is None:
        schedule = lambda x : x / 1.2
    current = problem.initial
    print("Initial: %s", current)
    T = 1
    for t in range(10000000):
        T = schedule(T)
        if T < 0.00000001: break
        successor = Neuron(*current.weights + np.random.default_rng().uniform(low=-2.-current.error, high=2.+current.error, size=Neuron.DIM_W))
        current = _anneal_step(problem, T, current, successor)
    static_order = problem.static_order()
    #print(f"Static Order: {tuple(static_order)}")
    print("Winner: %s", current)
    print("Path Length: %s", len(problem.graph.keys()))
    #print("graph: %s", problem.graph)
    if plt is not None and nx is not None:
        G = nx.DiGraph()
        for v, e, in problem.graph.items():
            print("%s: %s", v,e)
    return problem


if __name__ == "__main__":
    main()
# Out:
# executing anneal command
# initializing %s Neuron
# initializing %s ProblemGraph
# Initial: %s Neuron#3010437511937009226:(0, 0, 0). err=2.0
# initializing %s Neuron
# 0.1756082704141293
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.6990681070339291
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.3260334362680797
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.6060038570879649
# 0.9920398405582133
# initializing %s Neuron
# -0.2271259548140876
# 0.9900597211159813
# Taking successor with probability %d%s (exploration) 79.50054431762426 %
# initializing %s Neuron
# 0.013246366852497138
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.009717987262898076
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0032531593284446103
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -3.304638677015248e-05
# 0.9821786878790071
# Taking successor with probability %d%s (exploration) 99.99663545633346 %
# initializing %s Neuron
# 0.000217110487217953
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.5079974925512616e-05
# 0.9782617279204138
# Taking successor with probability %d%s (exploration) 99.99743630434257 %
# initializing %s Neuron
# -0.002025257192020513
# 0.9763091097010117
# Taking successor with probability %d%s (exploration) 99.79277484709847 %
# initializing %s Neuron
# 0.0012758594528332612
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0015571408211734195
# 0.9724155578075503
# Taking successor with probability %d%s (exploration) 99.83999692933251 %
# initializing %s Neuron
# 0.0021593582741721296
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.4808601380922326e-05
# 0.968537533523323
# Taking successor with probability %d%s (exploration) 99.99847104653566 %
# initializing %s Neuron
# -0.011533011815972216
# 0.9666043248735758
# Taking successor with probability %d%s (exploration) 98.81394263955364 %
# initializing %s Neuron
# 0.011263419994278046
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.000842858964750004
# 0.9627494759717847
# Taking successor with probability %d%s (exploration) 99.91249124052993 %
# initializing %s Neuron
# 0.0011988369704574176
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.00016617772320826063
# 0.9589100003304616
# Taking successor with probability %d%s (exploration) 99.98267164543047 %
# initializing %s Neuron
# -0.013656201053672268
# 0.9569960083138339
# Taking successor with probability %d%s (exploration) 98.58314698277572 %
# initializing %s Neuron
# 0.0037557033042852073
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.012881790923305658
# 0.9531794776851824
# Taking successor with probability %d%s (exploration) 98.65763623416551 %
# initializing %s Neuron
# 0.0032041090684566953
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.008746122548576984
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.05339548780331005
# 0.9474832011003017
# initializing %s Neuron
# 0.01054565481377212
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.010598251326922492
# 0.9437046078504684
# Taking successor with probability %d%s (exploration) 98.88323510379841 %
# initializing %s Neuron
# -0.0890980358437854
# 0.9418209659186312
# Taking successor with probability %d%s (exploration) 90.97350443164304 %
# initializing %s Neuron
# -0.0324243442223362
# 0.939941083751129
# Taking successor with probability %d%s (exploration) 96.60920636499115 %
# initializing %s Neuron
# -0.24656285098568165
# 0.938064953843442
# Taking successor with probability %d%s (exploration) 76.88633825625058 %
# initializing %s Neuron
# 0.31871376985698796
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.7344797806112306
# 0.9343239208643014
# initializing %s Neuron
# -0.22210463290352656
# 0.9324590028585842
# initializing %s Neuron
# 0.03876852896965022
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.20597504361910368
# 0.9287403265909142
# Taking successor with probability %d%s (exploration) 80.10924355907103 %
# initializing %s Neuron
# -0.05375552187591448
# 0.9268865534839463
# Taking successor with probability %d%s (exploration) 94.3653916173455 %
# initializing %s Neuron
# -0.45348836253583213
# 0.9250364805229006
# Taking successor with probability %d%s (exploration) 61.24803890152969 %
# initializing %s Neuron
# -0.07638596121511632
# 0.923190100322256
# Taking successor with probability %d%s (exploration) 92.058926072909 %
# initializing %s Neuron
# 0.066632416199786
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.13055378647135907
# 0.919508388733766
# Taking successor with probability %d%s (exploration) 86.76367356469358 %
# initializing %s Neuron
# -0.12683892425666166
# 0.917673042648469
# Taking successor with probability %d%s (exploration) 87.09088208550446 %
# initializing %s Neuron
# 0.006468319118118959
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.13379423452708394
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.03290887736306236
# 0.9121889553513849
# Taking successor with probability %d%s (exploration) 96.45661920118592 %
# initializing %s Neuron
# 0.2518188342799397
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.3821964662233488
# 0.9085511166801974
# Taking successor with probability %d%s (exploration) 65.66094430180746 %
# initializing %s Neuron
# -0.02944913889862999
# 0.9067376413974025
# Taking successor with probability %d%s (exploration) 96.80436250851952 %
# initializing %s Neuron
# -0.4717292870686398
# 0.9049277858257511
# Taking successor with probability %d%s (exploration) 59.37544510645159 %
# initializing %s Neuron
# 0.10182618998740312
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.520780576469714
# 0.9013189049304098
# initializing %s Neuron
# 0.3064872445558957
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.1284698002725333
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.04109422643945204
# 0.8959325512647457
# Taking successor with probability %d%s (exploration) 95.51684708360342 %
# initializing %s Neuron
# 0.03001611390144454
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.43419387172412716
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.020211580946472463
# 0.8905783868782068
# Taking successor with probability %d%s (exploration) 97.75606991657982 %
# initializing %s Neuron
# -0.011723480682760634
# 0.8888007853075915
# Taking successor with probability %d%s (exploration) 98.68963866370143 %
# initializing %s Neuron
# -0.006767755156196209
# 0.8870267318439037
# Taking successor with probability %d%s (exploration) 99.23993241108003 %
# initializing %s Neuron
# -0.30760901385643713
# 0.8852562194050935
# Taking successor with probability %d%s (exploration) 70.64659972800398 %
# initializing %s Neuron
# 0.19966692218698334
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.3479981208720915
# 0.8817257893445579
# Taking successor with probability %d%s (exploration) 67.38967318118193 %
# initializing %s Neuron
# -0.025740898411077406
# 0.8799658576292994
# Taking successor with probability %d%s (exploration) 97.1171547001154 %
# initializing %s Neuron
# 0.7398389564679513
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.28877594126548867
# 0.876456525700395
# Taking successor with probability %d%s (exploration) 71.9296813223967 %
# initializing %s Neuron
# -0.08285702621699076
# 0.8747071114774401
# Taking successor with probability %d%s (exploration) 90.96226355612158 %
# initializing %s Neuron
# 0.5671262609141023
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.2608656252310173
# 0.8712187515960494
# Taking successor with probability %d%s (exploration) 74.12435049219594 %
# initializing %s Neuron
# -0.536900121288266
# 0.8694797920120254
# initializing %s Neuron
# -0.3396969749181964
# 0.867744303405215
# Taking successor with probability %d%s (exploration) 67.60614653366478 %
# initializing %s Neuron
# -0.23884106754263423
# 0.86601227884752
# Taking successor with probability %d%s (exploration) 75.89691947475814 %
# initializing %s Neuron
# 0.33620452685791835
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.2781187702210979
# 0.8625585942361983
# Taking successor with probability %d%s (exploration) 72.43832756065869 %
# initializing %s Neuron
# 0.11410409890663553
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.11694602587444258
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.4360694129997804
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.3086061323324225
# 0.8556924902981948
# Taking successor with probability %d%s (exploration) 69.72224658343926 %
# initializing %s Neuron
# 0.09743048549358457
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.22407509263181358
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0854597092563174
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.05368613135711864
# 0.8488810416422817
# Taking successor with probability %d%s (exploration) 93.87149537145032 %
# initializing %s Neuron
# -0.9056868757782115
# 0.8471866683056704
# initializing %s Neuron
# -0.24017918288924678
# 0.8454956769517669
# Taking successor with probability %d%s (exploration) 75.27146420051672 %
# initializing %s Neuron
# -1.1442255054420705
# 0.8438080608301066
# initializing %s Neuron
# -1.243155803615994
# 0.8421238132036992
# initializing %s Neuron
# 0.4233083718383852
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.06044354138643482
# 0.8387653965558894
# Taking successor with probability %d%s (exploration) 93.047272835745 %
# initializing %s Neuron
# -0.17135385983128248
# 0.8370912141276342
# Taking successor with probability %d%s (exploration) 81.48904931361459 %
# initializing %s Neuron
# -0.5112174728659438
# 0.8354203733808725
# Taking successor with probability %d%s (exploration) 54.230406761761095 %
# initializing %s Neuron
# -1.1984931688350502
# 0.8337528676455813
# Taking successor with probability %d%s (exploration) 23.752839091380633 %
# initializing %s Neuron
# -0.020353999804754608
# 0.8320886902650512
# Taking successor with probability %d%s (exploration) 97.58354193316639 %
# initializing %s Neuron
# 0.0028802059208286046
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.00725651103671332
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.010195542999686502
# 0.8271160618840756
# Taking successor with probability %d%s (exploration) 98.77490444328099 %
# initializing %s Neuron
# 0.0049706410908072485
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.03667036218136088
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.7015131249452122
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.367151146654334
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.7854170227603767
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.5688191236829045
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.3781619125788468
# 0.8156285209615666
# initializing %s Neuron
# -0.44607819168512863
# 0.8140005199217232
# initializing %s Neuron
# 0.007128634565902736
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.3966330761999064
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.11293926176697186
# 0.809135987889444
# Taking successor with probability %d%s (exploration) 86.97233774324604 %
# initializing %s Neuron
# -0.7185046995285079
# 0.8075209459974491
# initializing %s Neuron
# -0.6941024350686468
# 0.8059091277419651
# Taking successor with probability %d%s (exploration) 42.26265385370499 %
# initializing %s Neuron
# -0.038058800277820604
# 0.804300526688588
# Taking successor with probability %d%s (exploration) 95.37829693295957 %
# initializing %s Neuron
# 0.08287387194566953
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.7497114779608394
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.010301024817675974
# 0.799493962589548
# Taking successor with probability %d%s (exploration) 98.71982179118987 %
# initializing %s Neuron
# -0.055008650049784474
# 0.7978981662570339
# Taking successor with probability %d%s (exploration) 93.33808676205624 %
# initializing %s Neuron
# -0.37244411239274255
# 0.7963055551467404
# Taking successor with probability %d%s (exploration) 62.643198440929936 %
# initializing %s Neuron
# 0.05172866751513794
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.49220761162045396
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.050970265535652134
# 0.7915467696353187
# Taking successor with probability %d%s (exploration) 93.76362057162633 %
# initializing %s Neuron
# 0.043934889775524594
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.014591778326714929
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.04268964203007089
# 0.7868164230056772
# Taking successor with probability %d%s (exploration) 94.71894382071794 %
# initializing %s Neuron
# 0.025284015608580297
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.2570831850674605
# 0.7836785739953996
# Taking successor with probability %d%s (exploration) 72.03293657433682 %
# initializing %s Neuron
# 0.16443606540692748
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0948714424279353
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.16429533961161358
# 0.7789952483304748
# Taking successor with probability %d%s (exploration) 80.98495989657592 %
# initializing %s Neuron
# -0.3001718330448094
# 0.7774403675952842
# initializing %s Neuron
# -0.48955249739721957
# 0.7758885904144553
# initializing %s Neuron
# -0.631409989579174
# 0.7743399105932688
# initializing %s Neuron
# 0.16335835055581796
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.09272174070994296
# 0.7712518183127446
# Taking successor with probability %d%s (exploration) 88.67232120194126 %
# initializing %s Neuron
# 0.06462144304238877
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.05015480370528328
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.01990301083825974
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.09456492420075643
# 0.7651125308692073
# Taking successor with probability %d%s (exploration) 88.37367108459487 %
# initializing %s Neuron
# 0.04809944791708165
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.020337260570805378
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.182954520375886
# 0.7605401573588446
# Taking successor with probability %d%s (exploration) 78.61885270564963 %
# initializing %s Neuron
# -0.0194531971177323
# 0.7590221131325795
# Taking successor with probability %d%s (exploration) 97.46963532728643 %
# initializing %s Neuron
# 0.18388413731827566
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.057006243553977654
# 0.7559951087172756
# Taking successor with probability %d%s (exploration) 92.736729589758 %
# initializing %s Neuron
# -0.07666821151491165
# 0.7544861364443868
# Taking successor with probability %d%s (exploration) 90.33759646015564 %
# initializing %s Neuron
# 0.14885659558706132
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0287490210549559
# 0.7514772216489045
# Taking successor with probability %d%s (exploration) 96.24658666991746 %
# initializing %s Neuron
# 0.036795572563181556
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.35480122011176596
# 0.7484803065016719
# initializing %s Neuron
# 0.02331035807370506
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.02561066764395422
# 0.7454953431477084
# Taking successor with probability %d%s (exploration) 96.62295017577485 %
# initializing %s Neuron
# -0.05236905493305976
# 0.7440073284907269
# Taking successor with probability %d%s (exploration) 93.20322877702118 %
# initializing %s Neuron
# 0.02692978332641826
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.003800676094591192
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.2897978063502269
# 0.7395610813531431
# Taking successor with probability %d%s (exploration) 67.58047492328406 %
# initializing %s Neuron
# 0.3232154375777895
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.011369646435517328
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.001993229237567175
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0019639170947316808
# 0.733674057228632
# Taking successor with probability %d%s (exploration) 99.73267544518244 %
# initializing %s Neuron
# -0.0025343922107132297
# 0.7322096379527265
# Taking successor with probability %d%s (exploration) 99.65446902108943 %
# initializing %s Neuron
# -0.001502799186538689
# 0.7307481416693877
# Taking successor with probability %d%s (exploration) 99.79455917978535 %
# initializing %s Neuron
# -0.020923462146903708
# 0.7292895625442991
# Taking successor with probability %d%s (exploration) 97.17174575878477 %
# initializing %s Neuron
# -0.15390627137322993
# 0.7278338947547895
# Taking successor with probability %d%s (exploration) 80.94033067967659 %
# initializing %s Neuron
# 0.14330665492514738
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.3495853646263628
# 0.7249312699499101
# initializing %s Neuron
# -0.5943085429562752
# 0.7234843013472156
# Taking successor with probability %d%s (exploration) 43.979205458928135 %
# initializing %s Neuron
# -0.009902767955473069
# 0.7220402209054049
# Taking successor with probability %d%s (exploration) 98.6378640795044 %
# initializing %s Neuron
# 0.566031656822383
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.14383604166977892
# 0.7191607014567719
# Taking successor with probability %d%s (exploration) 81.87263115535423 %
# initializing %s Neuron
# -0.09080959602043653
# 0.7177252509548622
# Taking successor with probability %d%s (exploration) 88.11528464746559 %
# initializing %s Neuron
# -0.3532102060458528
# 0.7162926656236149
# Taking successor with probability %d%s (exploration) 61.0724827755251 %
# initializing %s Neuron
# -0.09192493767294929
# 0.7148629397441266
# Taking successor with probability %d%s (exploration) 87.93335426379035 %
# initializing %s Neuron
# -0.23804168052802743
# 0.7134360676089088
# Taking successor with probability %d%s (exploration) 71.6300693330988 %
# initializing %s Neuron
# -0.003396767887707597
# 0.712012043521865
# Taking successor with probability %d%s (exploration) 99.5240700808025 %
# initializing %s Neuron
# 3.6104263314573615e-06
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -5.789902070285624e-05
# 0.709172516764739
# Taking successor with probability %d%s (exploration) 99.99183602637277 %
# initializing %s Neuron
# -7.617802880721669e-07
# 0.7077570027592206
# Taking successor with probability %d%s (exploration) 99.99989236703061 %
# initializing %s Neuron
# -1.8360435982689438e-07
# 0.7063443141309587
# Taking successor with probability %d%s (exploration) 99.99997400639712 %
# initializing %s Neuron
# -7.174319693881159e-09
# 0.7049344452404777
# Taking successor with probability %d%s (exploration) 99.99999898227136 %
# initializing %s Neuron
# 1.7109415773042258e-08
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 3.068494247582265e-08
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -4.867326031110508e-08
# 0.7007217007696768
# Taking successor with probability %d%s (exploration) 99.99999305383884 %
# initializing %s Neuron
# 1.347526534800636e-10
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.1071738970080958e-08
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.0212911404350322e-06
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -6.649465006391964e-07
# 0.6951438443072302
# Taking successor with probability %d%s (exploration) 99.9999043440882 %
# initializing %s Neuron
# 5.16693855456829e-06
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -3.164144452005857e-06
# 0.6923715884670083
# Taking successor with probability %d%s (exploration) 99.99954300013539 %
# initializing %s Neuron
# 4.103368094032778e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0002555163409762029
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.00661232649799981
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.005315613898966398
# 0.6868602002298477
# Taking successor with probability %d%s (exploration) 99.22908649002194 %
# initializing %s Neuron
# 0.0013530490275138751
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0023585117151841972
# 0.6841209798266219
# Taking successor with probability %d%s (exploration) 99.65584290498849 %
# initializing %s Neuron
# -0.0003845542543989833
# 0.6827554688888442
# Taking successor with probability %d%s (exploration) 99.94369199598668 %
# initializing %s Neuron
# 0.00019641412412818582
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.3393751671368136
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.10680442150221214
# 0.6786752677497306
# Taking successor with probability %d%s (exploration) 85.4386247015289 %
# initializing %s Neuron
# 0.5903420622655475
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.09740957559336577
# 0.6759686891185002
# initializing %s Neuron
# -0.12051425010542027
# 0.674619450218064
# Taking successor with probability %d%s (exploration) 83.64066646657176 %
# initializing %s Neuron
# -0.4456292464746572
# 0.6732729044092455
# initializing %s Neuron
# -0.5473653491942101
# 0.6719290463166122
# initializing %s Neuron
# -0.66355348310303
# 0.6705878705754613
# initializing %s Neuron
# 0.1330150459779008
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.12341034834492405
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.11179168936055235
# 0.6665803839743643
# Taking successor with probability %d%s (exploration) 84.55996658005115 %
# initializing %s Neuron
# -0.11128413233012482
# 0.6652498842059523
# Taking successor with probability %d%s (exploration) 84.59612694925912 %
# initializing %s Neuron
# 0.24255073189755105
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.019919623862105412
# 0.6625968464328352
# Taking successor with probability %d%s (exploration) 97.03844342122473 %
# initializing %s Neuron
# -0.21934031690711492
# 0.6612742978371609
# Taking successor with probability %d%s (exploration) 71.77073417488612 %
# initializing %s Neuron
# -0.09480661153252762
# 0.6599543890590428
# Taking successor with probability %d%s (exploration) 86.61853971737375 %
# initializing %s Neuron
# -0.07807575782241566
# 0.658637114829384
# Taking successor with probability %d%s (exploration) 88.8215053394477 %
# initializing %s Neuron
# -0.003777519692357234
# 0.6573224698896049
# Taking successor with probability %d%s (exploration) 99.4269652646366 %
# initializing %s Neuron
# -0.19521987154343767
# 0.6560104489916216
# Taking successor with probability %d%s (exploration) 74.26083243714417 %
# initializing %s Neuron
# -0.4315754192602175
# 0.6547010468978259
# Taking successor with probability %d%s (exploration) 51.72677548529004 %
# initializing %s Neuron
# 0.0869739775469649
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.046936873417677716
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0036182594833201742
# 0.6507885012221702
# Taking successor with probability %d%s (exploration) 99.44556185664263 %
# initializing %s Neuron
# 0.48530361869207805
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.3411330442454473
# 0.6481931359060026
# Taking successor with probability %d%s (exploration) 59.07968708268895 %
# initializing %s Neuron
# -0.04133073977002699
# 0.6468993372315395
# Taking successor with probability %d%s (exploration) 93.81076910852887 %
# initializing %s Neuron
# -0.1446831887616714
# 0.6456081209895603
# Taking successor with probability %d%s (exploration) 79.92322248073745 %
# initializing %s Neuron
# -0.2080526368644503
# 0.6443194820255093
# Taking successor with probability %d%s (exploration) 72.40441471109472 %
# initializing %s Neuron
# 0.1903083510051221
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.001842959004015876
# 0.6417499153643903
# Taking successor with probability %d%s (exploration) 99.71323482669838 %
# initializing %s Neuron
# 0.014220726091671465
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.017824314231444816
# 0.6391905962171369
# Taking successor with probability %d%s (exploration) 97.24994608156203 %
# initializing %s Neuron
# 0.002233150558802466
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0023947676548661256
# 0.6366414837163367
# Taking successor with probability %d%s (exploration) 99.624550186838 %
# initializing %s Neuron
# -0.0009110167232303512
# 0.635370742231873
# Taking successor with probability %d%s (exploration) 99.85671925838022 %
# initializing %s Neuron
# 0.00020133528749055607
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0003536188354984482
# 0.6328368634306965
# Taking successor with probability %d%s (exploration) 99.94413725303774 %
# initializing %s Neuron
# 2.286435373655138e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -4.0080463938996225e-05
# 0.630313089819061
# Taking successor with probability %d%s (exploration) 99.99364138389454 %
# initializing %s Neuron
# 5.6333203342084914e-06
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -5.411468329330482e-06
# 0.6277993810971481
# Taking successor with probability %d%s (exploration) 99.99913802957289 %
# initializing %s Neuron
# 2.4628880843646783e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.457869275740432e-05
# 0.6252956971258561
# Taking successor with probability %d%s (exploration) 99.9960693461005 %
# initializing %s Neuron
# -1.4099840885961612e-06
# 0.624047601922012
# Taking successor with probability %d%s (exploration) 99.9997740585027 %
# initializing %s Neuron
# -2.41536196599057e-08
# 0.6228019979261598
# Taking successor with probability %d%s (exploration) 99.999996121782 %
# initializing %s Neuron
# -5.877983849655877e-07
# 0.621558880165828
# Taking successor with probability %d%s (exploration) 99.99990543162912 %
# initializing %s Neuron
# -2.0904468090998662e-06
# 0.6203182436784711
# Taking successor with probability %d%s (exploration) 99.99966300470636 %
# initializing %s Neuron
# -8.412263965640321e-06
# 0.6190800835114482
# Taking successor with probability %d%s (exploration) 99.99864117631375 %
# initializing %s Neuron
# -5.015042335632103e-05
# 0.6178443947220041
# Taking successor with probability %d%s (exploration) 99.991883330417 %
# initializing %s Neuron
# -0.00021682967015124177
# 0.6166111723772496
# Taking successor with probability %d%s (exploration) 99.96484144943452 %
# initializing %s Neuron
# -0.0013521463627554908
# 0.6153804115541414
# Taking successor with probability %d%s (exploration) 99.78051593435808 %
# initializing %s Neuron
# -0.0016759127761598602
# 0.6141521073394625
# Taking successor with probability %d%s (exploration) 99.72748962358041 %
# initializing %s Neuron
# -0.26995283166980544
# 0.6129262548298029
# Taking successor with probability %d%s (exploration) 64.3757737114296 %
# initializing %s Neuron
# -0.6741970418904302
# 0.6117028491315398
# initializing %s Neuron
# -0.4965328999850738
# 0.6104818853608182
# Taking successor with probability %d%s (exploration) 44.33721309070705 %
# initializing %s Neuron
# -0.2262549148414177
# 0.6092633586435311
# initializing %s Neuron
# 0.7616797365267081
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.007086062954764216
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0004796215748228416
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0005385644299531478
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 4.738033204221281e-06
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.014104235497193e-05
# 0.6020031047353298
# Taking successor with probability %d%s (exploration) 99.99831546434558 %
# initializing %s Neuron
# 1.1790378985132577e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -3.918090916155137e-07
# 0.599602297137591
# Taking successor with probability %d%s (exploration) 99.99993465519303 %
# initializing %s Neuron
# -1.1482461448331094e-07
# 0.5984054861652605
# Taking successor with probability %d%s (exploration) 99.9999808115724 %
# initializing %s Neuron
# 9.660829156654671e-07
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 5.996735219504501e-08
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.398196351587444e-06
# 0.5948293672507142
# Taking successor with probability %d%s (exploration) 99.99976494188329 %
# initializing %s Neuron
# 1.3828378979674483e-06
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.731021015416445e-08
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.8826860870291284e-07
# 0.591274619508035
# Taking successor with probability %d%s (exploration) 99.99996815886011 %
# initializing %s Neuron
# 2.1082549639395154e-07
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 5.735166852538498e-08
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 3.117794689089237e-09
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.052196856894284e-09
# 0.5865679792628692
# Taking successor with probability %d%s (exploration) 99.99999965013487 %
# initializing %s Neuron
# -2.424916146326339e-06
# 0.585397184893083
# Taking successor with probability %d%s (exploration) 99.99958576652118 %
# initializing %s Neuron
# 2.34496229634118e-06
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.884941207814684e-05
# 0.5830626022337392
# Taking successor with probability %d%s (exploration) 99.99505221253122 %
# initializing %s Neuron
# 2.546079703846793e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 2.8284049404803113e-06
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -4.102797554805804e-06
# 0.5795781736173264
# Taking successor with probability %d%s (exploration) 99.99929210877498 %
# initializing %s Neuron
# -1.4037091989438366e-05
# 0.5784213309554156
# Taking successor with probability %d%s (exploration) 99.99757323582068 %
# initializing %s Neuron
# -0.0007928587191943226
# 0.5772667973606942
# Taking successor with probability %d%s (exploration) 99.86274726207817 %
# initializing %s Neuron
# -0.0035746707195067895
# 0.5761145682242457
# Taking successor with probability %d%s (exploration) 99.38144185643199 %
# initializing %s Neuron
# -0.004292900271663402
# 0.574964638946353
# Taking successor with probability %d%s (exploration) 99.25614314397447 %
# initializing %s Neuron
# -0.39421272776574856
# 0.57381700493648
# initializing %s Neuron
# 0.004262211250990688
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0028514820123839435
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0015427191053281053
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.227552428928469e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -4.843295082546106e-06
# 0.5681131038790191
# Taking successor with probability %d%s (exploration) 99.99914748059771 %
# initializing %s Neuron
# -2.6537550726013492e-05
# 0.5669791455878435
# Taking successor with probability %d%s (exploration) 99.99531959334041 %
# initializing %s Neuron
# -0.00030251077462395415
# 0.5658474506864705
# Taking successor with probability %d%s (exploration) 99.9465527457617 %
# initializing %s Neuron
# 0.0002569316062941418
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 7.443679270124903e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.0754120616685015e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 2.2912602204439025e-06
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.0844666520348767e-07
# 0.5602227692208359
# Taking successor with probability %d%s (exploration) 99.9999806422265 %
# initializing %s Neuron
# -5.462413030787872e-07
# 0.5591045601006347
# Taking successor with probability %d%s (exploration) 99.99990230073671 %
# initializing %s Neuron
# 6.434546062639157e-07
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.6262884594553384e-08
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 2.0833779146300913e-10
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -5.12556663778696e-11
# 0.5546539986576037
# Taking successor with probability %d%s (exploration) 99.99999999075898 %
# initializing %s Neuron
# 7.846145955170414e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -4.221845095742083e-11
# 0.5524420208062952
# Taking successor with probability %d%s (exploration) 99.99999999235784 %
# initializing %s Neuron
# 6.59738930153253e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.892630496769243e-10
# 0.5502388643932646
# Taking successor with probability %d%s (exploration) 99.99999996560346 %
# initializing %s Neuron
# -1.8734525042418682e-10
# 0.549140583226811
# Taking successor with probability %d%s (exploration) 99.99999996588393 %
# initializing %s Neuron
# -1.289193196640781e-10
# 0.5480444942383343
# Taking successor with probability %d%s (exploration) 99.99999997647649 %
# initializing %s Neuron
# 1.7674735008910147e-09
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -9.33096599986527e-10
# 0.5458588753016267
# Taking successor with probability %d%s (exploration) 99.999999829059 %
# initializing %s Neuron
# 1.1356828033548538e-08
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.725882770031717e-09
# 0.5436819726830039
# Taking successor with probability %d%s (exploration) 99.99999968255656 %
# initializing %s Neuron
# -9.95925897306904e-09
# 0.5425967791247543
# Taking successor with probability %d%s (exploration) 99.99999816451935 %
# initializing %s Neuron
# 2.614197969208476e-09
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 8.168679234143994e-07
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 3.4692666328606236e-07
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 6.8931531823746e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.00023388629157483631
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0006250039729474022
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 4.9447365808585886e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.000506104675335739
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.05126601465550651
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.06766361223200368
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.09915538857356554
# 0.5308016627106333
# Taking successor with probability %d%s (exploration) 82.96070816680273 %
# initializing %s Neuron
# 0.6975101938927905
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.12449106340076505
# 0.5286848087364525
# Taking successor with probability %d%s (exploration) 79.01969002402728 %
# initializing %s Neuron
# 0.19298451834191563
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.15318435727808352
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.20211759720706135
# 0.5255253461511887
# initializing %s Neuron
# 0.014585368649913596
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.01825364328446301
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0006487499604819168
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.04260018913082207
# 0.5213420806051252
# Taking successor with probability %d%s (exploration) 92.15368193866689 %
# initializing %s Neuron
# -0.453486776012567
# 0.5203014776498256
# Taking successor with probability %d%s (exploration) 41.82881876595141 %
# initializing %s Neuron
# 0.14868670015862395
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.2649902937438975
# 0.5182264987488353
# Taking successor with probability %d%s (exploration) 59.969104180416466 %
# initializing %s Neuron
# -0.30427064780897206
# 0.5171921145197957
# Taking successor with probability %d%s (exploration) 55.52634352437038 %
# initializing %s Neuron
# -0.04451132236208588
# 0.5161597949299359
# initializing %s Neuron
# 0.05568881563324024
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.09589704292198653
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.14266847878023736
# 0.5130751828261835
# Taking successor with probability %d%s (exploration) 75.7247262215714 %
# initializing %s Neuron
# -0.016936724533409553
# 0.5120510806648537
# Taking successor with probability %d%s (exploration) 96.74647970776834 %
# initializing %s Neuron
# -0.047931779497704774
# 0.5110290226196145
# Taking successor with probability %d%s (exploration) 91.04697237118185 %
# initializing %s Neuron
# -0.0013186946686614132
# 0.5100090046103937
# Taking successor with probability %d%s (exploration) 99.7417709693752 %
# initializing %s Neuron
# 0.001170160160520295
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.003205860851567266
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.004352900230149004
# 0.5069611501201821
# Taking successor with probability %d%s (exploration) 99.1450496683146 %
# initializing %s Neuron
# 0.0003118898785926527
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0003114970350461821
# 0.5049393728712057
# Taking successor with probability %d%s (exploration) 99.93832903705068 %
# initializing %s Neuron
# 0.009642877215979784
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.022382907713405675
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.30720008024230494
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.30937437800852663
# 0.5009199749547152
# initializing %s Neuron
# 0.6258722102336538
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.029131266085608953
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.003205287281196395
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0022101163130840017
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0002950987437134536
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.4179596725938574e-05
# 0.49495078912683604
# Taking successor with probability %d%s (exploration) 99.99713519122966 %
# initializing %s Neuron
# -0.00010361717663924046
# 0.493962863400036
# Taking successor with probability %d%s (exploration) 99.97902548605646 %
# initializing %s Neuron
# -0.00031851333004714877
# 0.49297690958087426
# Taking successor with probability %d%s (exploration) 99.93541067543367 %
# initializing %s Neuron
# 0.0003383159281247304
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 2.80462762077381e-05
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -6.82251634333315e-05
# 0.49003084024905025
# Taking successor with probability %d%s (exploration) 99.9860783426913 %
# initializing %s Neuron
# -0.001062239492737004
# 0.48905273477949124
# Taking successor with probability %d%s (exploration) 99.78303224958157 %
# initializing %s Neuron
# 0.0008243315465920881
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.00032225627540386967
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.00015676448173755565
# 0.48613011662927513
# Taking successor with probability %d%s (exploration) 99.96775776631968 %
# initializing %s Neuron
# -0.0018378027060783483
# 0.48515979703520473
# Taking successor with probability %d%s (exploration) 99.62191297031858 %
# initializing %s Neuron
# -0.0023956843770915645
# 0.4841914142067911
# Taking successor with probability %d%s (exploration) 99.50644158883817 %
# initializing %s Neuron
# -0.014594456356052951
# 0.48322496427823464
# Taking successor with probability %d%s (exploration) 97.0249330623875 %
# initializing %s Neuron
# -0.023712388690328035
# 0.48226044339145174
# Taking successor with probability %d%s (exploration) 95.20199780248527 %
# initializing %s Neuron
# 0.0006658153882249385
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.03960894972734843
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0012318287446728754
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.010140511340651415
# 0.47842157336958907
# Taking successor with probability %d%s (exploration) 97.90272863255758 %
# initializing %s Neuron
# -0.36210062279597216
# 0.47746664008941025
# initializing %s Neuron
# 0.00960794146935941
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0017041879010073516
# 0.47556248788790706
# Taking successor with probability %d%s (exploration) 99.64228926957182 %
# initializing %s Neuron
# -0.005342190663014388
# 0.47461326136517673
# Taking successor with probability %d%s (exploration) 98.8807228851996 %
# initializing %s Neuron
# -0.03895421323006346
# 0.4736659295061644
# Taking successor with probability %d%s (exploration) 92.10510215418842 %
# initializing %s Neuron
# 0.035912189130637526
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.009681691672462658
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.007974803885890901
# 0.47083526413152355
# Taking successor with probability %d%s (exploration) 98.32050670485619 %
# initializing %s Neuron
# -0.02928821181193301
# 0.46989547318515323
# Taking successor with probability %d%s (exploration) 93.95735224999369 %
# initializing %s Neuron
# -0.09867881921145844
# 0.4689575580690152
# initializing %s Neuron
# 0.02204191648757163
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.00410193637747258
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.011749566939463678
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.014612272275314756
# 0.4652245811353549
# Taking successor with probability %d%s (exploration) 96.90790690562324 %
# initializing %s Neuron
# -0.04037557596942891
# 0.46429598915704084
# Taking successor with probability %d%s (exploration) 91.6712980096225 %
# initializing %s Neuron
# -0.004933508673694582
# 0.46336925065572937
# Taking successor with probability %d%s (exploration) 98.94094439605682 %
# initializing %s Neuron
# -0.024971096720157987
# 0.4624443619318656
# Taking successor with probability %d%s (exploration) 94.74339479680752 %
# initializing %s Neuron
# -0.29555403498837474
# 0.46152131929327905
# Taking successor with probability %d%s (exploration) 52.70863663214042 %
# initializing %s Neuron
# -0.17240615872915427
# 0.46060011905516873
# Taking successor with probability %d%s (exploration) 68.77652724948558 %
# initializing %s Neuron
# -0.4308573546254838
# 0.4596807575400886
# initializing %s Neuron
# -0.43543818422459324
# 0.4587632310779327
# Taking successor with probability %d%s (exploration) 38.70673083768191 %
# initializing %s Neuron
# 0.11047436395216337
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.10559417325357323
# 0.4569336686685837
# initializing %s Neuron
# 0.5457323541051775
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.3069747913942634
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.011473987737632542
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.06394031881519179
# 0.45329640381166125
# Taking successor with probability %d%s (exploration) 86.84404069906475 %
# initializing %s Neuron
# -0.30956711698323414
# 0.45239162057052024
# initializing %s Neuron
# 0.07432565493158036
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.001933258394936869
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0023935241838249632
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.004224824249821707
# 0.44879051114065066
# Taking successor with probability %d%s (exploration) 99.06303708002866 %
# initializing %s Neuron
# -0.017944250637650712
# 0.44789472169725614
# Taking successor with probability %d%s (exploration) 96.07283870844005 %
# initializing %s Neuron
# 0.019115906725679345
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.002337823666183913
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0003745401933387795
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.0073360895631277775
# 0.4443294082994113
# Taking successor with probability %d%s (exploration) 98.36250759179744 %
# initializing %s Neuron
# 0.006325327749287745
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0005847413969398674
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0007006182756183883
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.00018222614023205802
# 0.44079247536467325
# Taking successor with probability %d%s (exploration) 99.95866796986382 %
# initializing %s Neuron
# -0.00033138704450450733
# 0.43991265006454416
# Taking successor with probability %d%s (exploration) 99.92469817393453 %
# initializing %s Neuron
# -0.0010754701073903093
# 0.43903458090273867
# Taking successor with probability %d%s (exploration) 99.75533728326043 %
# initializing %s Neuron
# -0.1306077437910068
# 0.4381582643739907
# Taking successor with probability %d%s (exploration) 74.22393689951149 %
# initializing %s Neuron
# 0.007370968614780066
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.11273331895057737
# 0.43641087522957145
# Taking successor with probability %d%s (exploration) 77.23486399681734 %
# initializing %s Neuron
# -0.5768688482552973
# 0.43553979563829487
# initializing %s Neuron
# -0.014488804064420685
# 0.4346704547288372
# Taking successor with probability %d%s (exploration) 96.72165702006077 %
# initializing %s Neuron
# 0.24645740846533054
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.03096158845999144
# 0.4329369750806144
# Taking successor with probability %d%s (exploration) 93.09820962391632 %
# initializing %s Neuron
# -0.013161755488547373
# 0.4320728294217709
# Taking successor with probability %d%s (exploration) 96.99973968709944 %
# initializing %s Neuron
# -0.09515331570543006
# 0.4312104086045618
# Taking successor with probability %d%s (exploration) 80.19847965543909 %
# initializing %s Neuron
# 0.11436726313960867
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0271732731606671
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.06316320629398864
# 0.42863346080910975
# Taking successor with probability %d%s (exploration) 86.29836914414865 %
# initializing %s Neuron
# 0.06469183693566781
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0003571295626817071
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -0.01127185229413193
# 0.4260719130592224
# Taking successor with probability %d%s (exploration) 97.38915940732377 %
# initializing %s Neuron
# 0.011502610764549788
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.001052457098916625
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0003969671823722533
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 0.0002171141217922332
# Taking successor as better option (exploitation)
# initializing %s Neuron
# ...
# Taking successor with probability %d%s (exploration) 99.99811631089864 %
# initializing %s Neuron
# 3.8413716652030416e-14
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 2.580158309228864e-13
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.4432899320127035e-14
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -9.57012247226885e-14
# 1.2980128822402163e-08
# Taking successor with probability %d%s (exploration) 99.9992627124643 %
# initializing %s Neuron
# -2.842170943040401e-14
# 1.2954220381638886e-08
# Taking successor with probability %d%s (exploration) 99.99978059908344 %
# initializing %s Neuron
# -2.0694557179012918e-12
# 1.2928363654330225e-08
# Taking successor with probability %d%s (exploration) 99.98399418401142 %
# initializing %s Neuron
# 1.6791013024430868e-12
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.4098500972513648e-12
# 1.2876804927400911e-08
# Taking successor with probability %d%s (exploration) 99.98128709235488 %
# initializing %s Neuron
# -4.689759691700601e-11
# 1.2851102721956997e-08
# Taking successor with probability %d%s (exploration) 99.6357345349761 %
# initializing %s Neuron
# 2.6983748568909505e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.833977414378296e-11
# 1.2799852114092171e-08
# Taking successor with probability %d%s (exploration) 99.8568214575101 %
# initializing %s Neuron
# 3.157030192824095e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 9.3975938142421e-12
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.6855405959859127e-12
# 1.2723359176933573e-08
# Taking successor with probability %d%s (exploration) 99.98675327065297 %
# initializing %s Neuron
# -9.72333324966712e-13
# 1.2697963250432708e-08
# Taking successor with probability %d%s (exploration) 99.99234289721088 %
# initializing %s Neuron
# -7.136646829053461e-11
# 1.26726180144039e-08
# Taking successor with probability %d%s (exploration) 99.43842785268289 %
# initializing %s Neuron
# -1.2418519546031348e-09
# 1.2647323367668563e-08
# Taking successor with probability %d%s (exploration) 90.6475848842871 %
# initializing %s Neuron
# 1.1478951122967374e-09
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.3767077195202546e-10
# 1.2596885438373317e-08
# Taking successor with probability %d%s (exploration) 98.13094522225201 %
# initializing %s Neuron
# -4.0047527516406944e-09
# 1.257174195446439e-08
# Taking successor with probability %d%s (exploration) 72.72013082867583 %
# initializing %s Neuron
# -5.4101840452069894e-08
# 1.2546648657150089e-08
# initializing %s Neuron
# -7.373484856021406e-08
# 1.2521605446257574e-08
# initializing %s Neuron
# -3.8829183979238735e-08
# 1.2496612221813945e-08
# initializing %s Neuron
# -3.8506331456744647e-10
# 1.2471668884045854e-08
# Taking successor with probability %d%s (exploration) 96.95967232884458 %
# initializing %s Neuron
# 4.372874728986176e-09
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 3.704907491908216e-10
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 4.643196938047822e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 3.97326616052851e-12
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.0609291223317996e-12
# 1.2347697017189303e-08
# Taking successor with probability %d%s (exploration) 99.99140824767565 %
# initializing %s Neuron
# 9.134915046615788e-13
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -3.141753524005253e-11
# 1.2298454007343898e-08
# Taking successor with probability %d%s (exploration) 99.74486679484224 %
# initializing %s Neuron
# -6.484286441121867e-10
# 1.227390619495399e-08
# Taking successor with probability %d%s (exploration) 94.85413914538657 %
# initializing %s Neuron
# 9.167377967855828e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 5.327034369173589e-10
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 2.7572388816565763e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 6.269429420058259e-12
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -6.782625572299139e-10
# 1.2151900144379863e-08
# Taking successor with probability %d%s (exploration) 94.57137460062738 %
# initializing %s Neuron
# -5.657823098914605e-10
# 1.2127644854670521e-08
# Taking successor with probability %d%s (exploration) 95.44192084690191 %
# initializing %s Neuron
# 1.2259349091436889e-09
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 3.243338930758455e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.5059953284435323e-11
# 1.2055169081709927e-08
# Taking successor with probability %d%s (exploration) 99.87515272283409 %
# initializing %s Neuron
# 1.4127365943750192e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.3422597195121853e-11
# 1.200709268260876e-08
# Taking successor with probability %d%s (exploration) 99.80511713302427 %
# initializing %s Neuron
# -1.609299360438854e-10
# 1.1983126429749262e-08
# Taking successor with probability %d%s (exploration) 98.66600643063083 %
# initializing %s Neuron
# -1.2157186368710882e-10
# 1.1959208013721818e-08
# Taking successor with probability %d%s (exploration) 98.98859498079958 %
# initializing %s Neuron
# 2.92596391560096e-10
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.9330759215563376e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 3.0748736890018336e-12
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.0720313525780512e-12
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 9.192646643896295e-14
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 5.5289106626331956e-14
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.9984014443235277e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 8.881784196990216e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -4.440892098501257e-15
# 1.1746079234989406e-08
# Taking successor with probability %d%s (exploration) 99.9999621925651 %
# initializing %s Neuron
# 5.329070518159071e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.2564710257804764e-25
# 1.1699235496063168e-08
# Taking successor with probability %d%s (exploration) 100.0 %
# initializing %s Neuron
# 3.017861348632845e-26
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 2.2204460445219688e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.2204460433504345e-16
# 1.162931993159983e-08
# Taking successor with probability %d%s (exploration) 99.99999809064843 %
# initializing %s Neuron
# 2.220446048368375e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.2204460522364055e-16
# 1.158294183250249e-08
# Taking successor with probability %d%s (exploration) 99.99999808300338 %
# initializing %s Neuron
# 2.2204460461856134e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -4.587859207139754e-25
# 1.1536748690744748e-08
# Taking successor with probability %d%s (exploration) 100.0 %
# initializing %s Neuron
# -4.4408920873043795e-16
# 1.1513721248248251e-08
# Taking successor with probability %d%s (exploration) 99.99999614295682 %
# initializing %s Neuron
# -8.881784196537237e-16
# 1.149073976871083e-08
# Taking successor with probability %d%s (exploration) 99.99999227048559 %
# initializing %s Neuron
# -4.640732242932184e-14
# 1.1467804160390049e-08
# Taking successor with probability %d%s (exploration) 99.99959532594139 %
# initializing %s Neuron
# 3.774758283725537e-14
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.5543122344751624e-14
# 1.1422070191343908e-08
# Taking successor with probability %d%s (exploration) 99.999863920362 %
# initializing %s Neuron
# 3.3306690738754917e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.9095836023552674e-14
# 1.137651861082616e-08
# Taking successor with probability %d%s (exploration) 99.99983214706845 %
# initializing %s Neuron
# 3.6415315207705135e-14
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -8.88178419700134e-16
# 1.1331148691465533e-08
# Taking successor with probability %d%s (exploration) 99.99999216162095 %
# initializing %s Neuron
# -2.220446049250463e-16
# 1.1308531628209114e-08
# Taking successor with probability %d%s (exploration) 99.99999803648599 %
# initializing %s Neuron
# 3.552713678800517e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.7763568394002444e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 4.440892098499882e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.7496732927609893e-28
# 1.1218513913396084e-08
# Taking successor with probability %d%s (exploration) 100.0 %
# initializing %s Neuron
# -1.776356839399897e-15
# 1.1196121670055971e-08
# Taking successor with probability %d%s (exploration) 99.99998413417832 %
# initializing %s Neuron
# -9.325873406851307e-15
# 1.1173774121812346e-08
# Taking successor with probability %d%s (exploration) 99.9999165378733 %
# initializing %s Neuron
# -1.9761969838327783e-14
# 1.1151471179453439e-08
# Taking successor with probability %d%s (exploration) 99.99982278614176 %
# initializing %s Neuron
# -3.4638958368304884e-14
# 1.1129212753945548e-08
# Taking successor with probability %d%s (exploration) 99.99968875692083 %
# initializing %s Neuron
# 5.2624571367232414e-14
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.998401444325296e-15
# 1.1084829098236211e-08
# Taking successor with probability %d%s (exploration) 99.99998197174492 %
# initializing %s Neuron
# 3.99680288865057e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 4.44089209850053e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 4.884981308348639e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 8.881784196924958e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.1102230246169145e-15
# 1.0974642805618058e-08
# Taking successor with probability %d%s (exploration) 99.99998988374394 %
# initializing %s Neuron
# 1.3322676295500425e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.220446049314266e-16
# 1.0930875579796552e-08
# Taking successor with probability %d%s (exploration) 99.9999979686476 %
# initializing %s Neuron
# -1.3322676295603967e-15
# 1.0909057464866819e-08
# Taking successor with probability %d%s (exploration) 99.99998778751004 %
# initializing %s Neuron
# 1.9984014443025744e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 2.22044604413406e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -4.28670210345352e-24
# 1.084386406734304e-08
# Taking successor with probability %d%s (exploration) 99.99999999999996 %
# initializing %s Neuron
# -4.4408920526472947e-16
# 1.0822219628086868e-08
# Taking successor with probability %d%s (exploration) 99.99999589650542 %
# initializing %s Neuron
# 2.2204460483702835e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -4.4408920953002323e-16
# 1.0779060270762735e-08
# Taking successor with probability %d%s (exploration) 99.99999588007499 %
# initializing %s Neuron
# 6.661338143685562e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.2204460459712269e-16
# 1.0736073034333264e-08
# Taking successor with probability %d%s (exploration) 99.99999793178938 %
# initializing %s Neuron
# -1.3322676295000948e-15
# 1.0714643746839585e-08
# Taking successor with probability %d%s (exploration) 99.9999875659184 %
# initializing %s Neuron
# -1.5765166949644192e-14
# 1.0693257232374835e-08
# Taking successor with probability %d%s (exploration) 99.99985256919398 %
# initializing %s Neuron
# -1.620925615951507e-14
# 1.0671913405563708e-08
# Taking successor with probability %d%s (exploration) 99.99984811304932 %
# initializing %s Neuron
# -1.8252066524837112e-13
# 1.0650612181201306e-08
# Taking successor with probability %d%s (exploration) 99.99828630412775 %
# initializing %s Neuron
# -1.3524736885983657e-12
# 1.06293534742528e-08
# Taking successor with probability %d%s (exploration) 99.98727685882794 %
# initializing %s Neuron
# 8.171241461241152e-14
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.3080647676133518e-12
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -6.128431095930783e-13
# 1.0565831610086307e-08
# Taking successor with probability %d%s (exploration) 99.99419993277027 %
# initializing %s Neuron
# 1.0813572259848893e-13
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 6.474820679613735e-13
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -9.048317650694848e-13
# 1.050268935764662e-08
# Taking successor with probability %d%s (exploration) 99.9913851323345 %
# initializing %s Neuron
# -3.708144902248045e-13
# 1.0481725905834951e-08
# Taking successor with probability %d%s (exploration) 99.99646233898464 %
# initializing %s Neuron
# -6.451728040701706e-12
# 1.046080429724047e-08
# Taking successor with probability %d%s (exploration) 99.93834375726344 %
# initializing %s Neuron
# -1.4699352846037073e-11
# 1.0439924448343782e-08
# Taking successor with probability %d%s (exploration) 99.85929965803703 %
# initializing %s Neuron
# 2.015521083365001e-11
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -3.448352714485841e-13
# 1.0398289696399398e-08
# Taking successor with probability %d%s (exploration) 99.9966837858557 %
# initializing %s Neuron
# 2.39386288569658e-12
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 1.8185453143324812e-13
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 7.216449659832981e-14
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 8.881784087715389e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 2.8865796379798697e-15
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 4.440876389492074e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -3.720312078127771e-21
# 1.0253871296230266e-08
# Taking successor with probability %d%s (exploration) 99.99999999996372 %
# initializing %s Neuron
# 2.2204347611228034e-16
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -1.2323806132291297e-20
# 1.0212978530195363e-08
# Taking successor with probability %d%s (exploration) 99.99999999987934 %
# initializing %s Neuron
# -3.597603903193194e-19
# 1.0192593343508347e-08
# Taking successor with probability %d%s (exploration) 99.99999999647038 %
# initializing %s Neuron
# -4.3299890673459376e-19
# 1.0172248845816713e-08
# Taking successor with probability %d%s (exploration) 99.99999999574332 %
# initializing %s Neuron
# -4.578983977210423e-19
# 1.0151944955904904e-08
# Taking successor with probability %d%s (exploration) 99.99999999548955 %
# initializing %s Neuron
# -1.1371391756396636e-18
# 1.0131681592719464e-08
# Taking successor with probability %d%s (exploration) 99.9999999887764 %
# initializing %s Neuron
# 1.6676049857693169e-18
# Taking successor as better option (exploitation)
# initializing %s Neuron
# 4.83013025062511e-19
# Taking successor as better option (exploitation)
# initializing %s Neuron
# -2.050441529000854e-18
# 1.0071133855411659e-08
# Taking successor with probability %d%s (exploration) 99.9999999796404 %
# initializing %s Neuron
# -2.7453096974500872e-18
# 1.0051031791828003e-08
# Taking successor with probability %d%s (exploration) 99.9999999726863 %
# initializing %s Neuron
# -4.8948182184743775e-18
# 1.0030969852123757e-08
# Taking successor with probability %d%s (exploration) 99.99999995120294 %
# initializing %s Neuron
# -6.292986920752397e-17
# 1.0010947956211334e-08
# Taking successor with probability %d%s (exploration) 99.9999993713895 %
# Winner: %s Neuron#5042266870961766952:(128.07779814149575, 84.2854847644454, -175.20551884802686). err=7.287660117665017e-17
# Path Length: %s 8728
